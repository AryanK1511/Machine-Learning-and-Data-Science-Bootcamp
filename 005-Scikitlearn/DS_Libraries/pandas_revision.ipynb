# %% [markdown]
# # Pandas Revision

# %%
import pandas as pd

# %%
colors = pd.Series(["Red", "Yellow", "Blue"])
colors
# Out:
# 0       Red
# 1    Yellow
# 2      Blue
# dtype: object

# %%
car_types = pd.Series(["BMW", "Mercedes", "Mazda"])
car_types
# Out:
# 0         BMW
# 1    Mercedes
# 2       Mazda
# dtype: object

# %%
cars_df = pd.DataFrame(
    {"Car Make": car_types
    , "Color": colors}
)

# %%
cars_df
# Out:
#    Car Make   Color
# 0       BMW     Red
# 1  Mercedes  Yellow
# 2     Mazda    Blue

# %%
car_sales = pd.read_csv("assets/car-sales-extended.csv")
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
car_sales.to_csv("assets/try.csv", index=False)

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)        Doors         Price
# count    1000.000000  1000.000000   1000.000000
# mean   131073.708000     4.014000  16045.665000
# std     68859.723885     0.379405   8630.794219
# min     10148.000000     3.000000   2796.000000
# 25%     71238.000000     4.000000   9481.500000
# 50%    131202.000000     4.000000  14264.000000
# 75%    192372.750000     4.000000  20738.750000
# max    249860.000000     5.000000  52458.000000

# %%
import numpy as np
numbers = pd.Series(np.random.randint(1, 10, 10))
numbers
# Out:
# 0    7
# 1    8
# 2    3
# 3    1
# 4    8
# 5    9
# 6    3
# 7    1
# 8    8
# 9    6
# dtype: int64

# %%
numbers.dtype
# Out:
# dtype('int64')

# %%
numbers.mean()
# Out:
# 5.4

# %%
numbers.sum()
# Out:
# 54

# %%
numbers.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10 entries, 0 to 9
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 10 non-null     int64
# dtypes: int64(1)
# memory usage: 212.0 bytes

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales)
# Out:
# 1000

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043
# 5   Honda    Red          42652      4  23883
# 6  Toyota   Blue         163453      4   8473

# %%
car_sales.tail()
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732

# %%
car_sales.iloc[3]
# Out:
# Make             Toyota
# Colour            White
# Odometer (KM)    154365
# Doors                 4
# Price             13434
# Name: 3, dtype: object

# %%
car_sales.loc[3]
# Out:
# Make             Toyota
# Colour            White
# Odometer (KM)    154365
# Doors                 4
# Price             13434
# Name: 3, dtype: object

# %%
new_series = pd.Series(["A", "B", "C", "D"], index=[1, 2, 3, 3])

# %%
new_series.loc[3] # Label based indexing
# Out:
# 3    C
# 3    D
# dtype: object

# %%
new_series.iloc[3] # Integer location based indexing
# Out:
# 'D'

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 1       BMW   Blue         192714      5  19943
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# 6    Toyota   Blue         163453      4   8473
# 8    Nissan  White         130538      4   9374
# ..      ...    ...            ...    ...    ...
# 993  Nissan  Black         162523      4   4696
# 994     BMW   Blue         163322      3  31666
# 996  Nissan  White         155144      3   5716
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [627 rows x 5 columns]

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors    3    4   5
# Make
# BMW     21    0  79
# Honda    0  304   0
# Nissan  44  154   0
# Toyota   0  398   0

# %%
car_sales.groupby(["Make"])[["Odometer (KM)", "Doors"]].mean()
# Out:
#         Odometer (KM)     Doors
# Make
# BMW     123540.800000  4.580000
# Honda   124667.671053  4.000000
# Nissan  135480.308081  3.777778
# Toyota  135667.223618  4.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

car_sales["Odometer (KM)"].head().plot();

# %%
car_sales["Odometer (KM)"].hist();

# %%
car_sales_missing = pd.read_csv("assets/car-sales-extended-missing-data.csv")
car_sales_missing.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
car_sales_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  950 non-null    float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
car_sales_missing["Make"].str.lower()
# Out:
# 0       honda
# 1         bmw
# 2       honda
# 3      toyota
# 4      nissan
#         ...
# 995    toyota
# 996       NaN
# 997    nissan
# 998     honda
# 999    toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales_missing["Make"].str.capitalize()
# Out:
# 0       Honda
# 1         Bmw
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996       NaN
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales_missing.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
car_sales_missing["Random Numbers"] = np.random.randint(100, 1000, len(car_sales_missing))
car_sales_missing.head(20)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price  Random Numbers
# 0    Honda  White        35431.0    4.0  15323.0             635
# 1      BMW   Blue       192714.0    5.0  19943.0             187
# 2    Honda  White        84714.0    4.0  28343.0             753
# 3   Toyota  White       154365.0    4.0  13434.0             479
# 4   Nissan   Blue       181577.0    3.0  14043.0             444
# 5    Honda    Red        42652.0    4.0  23883.0             840
# 6   Toyota   Blue       163453.0    4.0   8473.0             594
# 7    Honda  White            NaN    4.0  20306.0             693
# 8      NaN  White       130538.0    4.0   9374.0             607
# 9    Honda   Blue        51029.0    4.0  26683.0             894
# 10  Nissan  White       167421.0    4.0  16259.0             431
# 11  Nissan  Green        17119.0    4.0   6160.0             100
# 12  Nissan  White       102303.0    4.0  16909.0             620
# ...

# %%
len(car_sales_missing["Random Numbers"])
# Out:
# 1000

# %%
car_sales_missing.drop("Random Numbers", axis=1, inplace=True)
car_sales_missing.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
car_sales_sampled = car_sales_missing.sample(frac=1)

# %%
car_sales_sampled
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 479  Nissan  White       246825.0    3.0  13647.0
# 544   Honda  Black        27788.0    4.0  18919.0
# 854  Nissan  White       129883.0    4.0  23945.0
# 124  Nissan  Black        67364.0    NaN  15604.0
# 78   Toyota   Blue       238425.0    4.0   6502.0
# ..      ...    ...            ...    ...      ...
# 34    Honda   Blue        71949.0    4.0  17516.0
# 817  Toyota  White        95725.0    4.0  12523.0
# 86   Nissan   Blue            NaN    4.0   3300.0
# 371     NaN   Blue        23545.0    4.0  13932.0
# 639  Nissan  White        71103.0    4.0   6884.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing.reset_index(drop = True, inplace = True)

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing["Odometer (KM)"] = car_sales_missing["Odometer (KM)"].apply(lambda x: x / 2.5)
car_sales_missing.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        14172.4    4.0  15323.0
# 1     BMW   Blue        77085.6    5.0  19943.0
# 2   Honda  White        33885.6    4.0  28343.0
# 3  Toyota  White        61746.0    4.0  13434.0
# 4  Nissan   Blue        72630.8    3.0  14043.0

# %%
car_sales_missing_copy = car_sales_missing
car_sales_missing["Odometer (KM)"] = car_sales_missing["Odometer (KM)"].apply(lambda x: x * 2.5)
car_sales_missing.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
car_sales_missing["Odometer (KM)"] = car_sales_missing["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales_missing.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White      22144.375    4.0  15323.0
# 1     BMW   Blue     120446.250    5.0  19943.0
# 2   Honda  White      52946.250    4.0  28343.0
# 3  Toyota  White      96478.125    4.0  13434.0
# 4  Nissan   Blue     113485.625    3.0  14043.0

# %%
car_sales_missing = car_sales_missing.rename(columns={"Odometer (KM)": "Odometer (Miles)"})
car_sales_missing
# Out:
#        Make Colour  Odometer (Miles)  Doors    Price
# 0     Honda  White         22144.375    4.0  15323.0
# 1       BMW   Blue        120446.250    5.0  19943.0
# 2     Honda  White         52946.250    4.0  28343.0
# 3    Toyota  White         96478.125    4.0  13434.0
# 4    Nissan   Blue        113485.625    3.0  14043.0
# ..      ...    ...               ...    ...      ...
# 995  Toyota  Black         22387.500    4.0  32042.0
# 996     NaN  White         96965.000    3.0   5716.0
# 997  Nissan   Blue         41627.500    4.0  31570.0
# 998   Honda  White        134926.875    4.0   4001.0
# 999  Toyota   Blue        155225.000    4.0  12732.0
#
# [1000 rows x 5 columns]
